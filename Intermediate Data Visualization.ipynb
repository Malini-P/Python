# %% [markdown]
# ## Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
mtcars_updated_data = pd.read_csv("mtcars_updated.csv")
mtcars_updated_data.head(7)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4

# %% [markdown]
# ### 1. Univariate Analysis
#
# **Important Charts:**
#
# * Histogram
# * CountPlot
# * Pie Chart

# %% [markdown]
# ### 1.1 Histogram
#
# If you want to understand the distribution of one continuous data, we use Histogram

# %%
plt.hist(mtcars_updated_data["mpg"])   
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.title("MPG distribution")
plt.show()

# %% [markdown]
# ### 1.2 Countplot
#
# If you want to understand the distribution of one discrete data, we use Countplot

# %%
mtcars_updated_data.head(5)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ### NOTE:
#
# 1. Matplotlib doesn't have charts which Seaborn has.
# 2. Seaborn will not have some charts which matplotlib has.
# 3. Matplotlib and seaborn will have same charts

# %%
sns.countplot(data = mtcars_updated_data , x = "am" , y = None)
plt.title(" Automatic Vs Manual Car Distribution")
plt.show()

# %% [markdown]
# ### 1.3 Pie Chart
#
# If you want to understand the distribution of one discrete data, but wanted to pass the discrete data with it value counts

# %%
plt.pie(data = mtcars_updated_data , x = "mpg")
plt.show()

# %%
mtcars_updated_data["cyl"].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plt.pie(x = mtcars_updated_data["cyl"].value_counts())
plt.show()

# %%
plt.pie(x = mtcars_updated_data["cyl"].value_counts() , labels = ["8 Cyl","4 Cyl" ,"2 Cyl"] , explode = [0.01,0.01,0.01] , autopct = "%1.0f%%")
plt.show()

# %% [markdown]
# ### 2. Bivariate Analysis
#
# **Important Charts:**
#
# * Barplot
# * Scatterplot

# %% [markdown]
# ### 2.1 Barplot
#
# when you want to compare the data distribution between one discrete variable vs one continuous variable

# %%
sns.barplot(data = mtcars_updated_data , x = "am" , y = "mpg")
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %% [markdown]
# ### 2.2 Scatterplot
#
# when you want to compare the data distribution between one continuous data variable

# %%
plt.scatter(x = "wt" , y = "mpg" , data = mtcars_updated_data)

# %%
sns.scatterplot(x = "wt" , y = "mpg" , data = mtcars_updated_data)
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %% [markdown]
# ### 3. Multivariate Analysis
#
# **Important Charts:**
#
# * Pairplot
# * HeatMap

# %% [markdown]
# ### 3.1 Pairplot

# %%
sns.pairplot(data = mtcars_updated_data)

# %% [markdown]
# ### 3.2 HeatMap
#
# To identify the Strength of relationship between 2 features
#
# * Pearson Correlation , Coefficient - ( -1 to +1 )
# * **If x increases, y decreases is called negatively correlated**
# * **If x increases, also y increases is called positively correlated**
# * Spearmen Correlation , Coefficient

# %%
mtcars_updated_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars_updated_data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 mtcars_updated_data.corr()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
del mtcars_updated_data["model"]

# %%
mtcars_updated_data.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
corr_matrix = mtcars_updated_data.corr().round(2)
corr_matrix
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %%
sns.heatmap(corr_matrix ,  annot = True)
plt.show()

# %% [markdown]
# ### NOTES:
#
# * 0 to 0.20 - Very Weak Correlation
# * 0.21 to 0.40 - Weak correlation
# * 0.41 to 0.60 - Normal/Standard Correlation
# * 0.61 to 0.80 - Strong Correlation
# * 0.81 to 1 - Very Strong Correlation
#
# Mostly this is used for continuous vs continuous data distribution

# %% [markdown]
# ### Interpretation
#
# mpg of a car is very strongly negatively correlated with respect to cylinders , which means when no. of cyl increases mpg of car decreases

# %% [markdown]
# ### =================================================================

# %% [markdown]
# # Advanced level of Data Visualization

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %% [markdown]
# ### NOTE:
#
# 1. Univariate charts can include more than one features.
# 2. Bivariate charts can include more than two features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset
penguins = sns.load_dataset("penguins")

# Plot histogram with KDE
sns.histplot(data=penguins, x="flipper_length_mm", kde=True, bins=20, color="skyblue")
plt.title("Flipper Length Distribution with KDE")
plt.show()

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data= mtcars_updated_data, x="mpg", hue="am", multiple="stack")
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>
